# %% [markdown]
# <a href="https://colab.research.google.com/github/rabianaz001/EDA-ASSIGNMENT/blob/main/EDA_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
df = pd.read_csv('/content/data.csv')

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head(10)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.0
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %% [markdown]
# **Scatter plot**

# %%
df.plot(kind = 'scatter',x = 'Pulse', y = 'Calories')
plt.legend(title ='calories per duration')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# HISTPLOT

# %%
plt.figure(figsize = (8,8))
sns.histplot(data = df , x = 'Calories')
plt.legend(title = 'Calories data')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# LINEPLOT

# %%
df['Pulse'].plot(kind='line', figsize=(8, 4), title='Pulse')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# 3D SCATTERPLOT

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Pulse'], df['Maxpulse'], df['Calories'])

ax.set_xlabel('Pulse')
ax.set_ylabel('Maxpulse')
ax.set_zlabel('Calories')

plt.show()

# %%
df.plot(kind='scatter', x='Pulse', y='Maxpulse', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.plot(kind='scatter', x='Duration', y='Pulse', s=32, alpha=.8)
plt.show()

# %%
df['Calories'].plot(kind='hist', bins=20, title='Calories',color = '#002d9c')
plt.show()

# %%
df['Maxpulse'].plot(kind='hist', bins=20, title='Maxpulse', color = 'hotpink',edgecolor='black')
plt.show()

# %%
sns.histplot(bins=10, color='lightgreen', edgecolor='red',kde = True,data = df)
plt.xlabel('Pulse')
plt.ylabel('Duration')
plt.title('Histogram with density plot')
plt.show()

# %%
df.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
Index = ['Duration', 'Pulse', 'Maxpulse', 'Calories']
Cols = ['A', 'B', 'C', 'D']
df  = pd.DataFrame(abs(np.random.randn(4, 4)), index=Index, columns=Cols)

sns.heatmap(df, annot=True)
# Out:
# <Axes: >

# %%
counts = df.value_counts()
counts
# Out:
# Duration  Pulse  Maxpulse  Calories
# 60        100    120       300.0       3
#           102    127       300.0       2
#           109    153       387.6       2
#           111    151       368.5       2
# 45        100    120       225.3       2
#                                       ..
#           118    141       341.0       1
#           122    149       335.4       1
#           123    152       321.0       1
#           129    103       242.0       1
# 300       108    143       1500.2      1
# Length: 157, dtype: int64

# %%
columns = df.columns
columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
plt.figure(figsize = (20,10))
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x="Pulse", y = "Maxpulse", data = df)
plt.show()
